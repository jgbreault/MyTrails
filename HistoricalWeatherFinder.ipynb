# %% [markdown]
# <b><font size="5">Historical Weather Finder</font></b>

# %% [markdown]
# The Historical Weather Finder fetches historical weather data for trails based on latitude and longitude. Data is averaged over 10 years to obtain climate data. For trails with a known start and end date, weather data can be obtained in addition to climate data. Thanks to Open-Meteo for the free API (https://open-meteo.com/en/docs/historical-weather-api).

# %%
### Imports

import numpy as np
import pandas as pd
import requests

# %%
### Defining Functions

# if there is an exisitng column, I use it; I build a new column from scratch otherwise
def getInitalArray(trails, col_name):
    if col_name in trails.columns:
        return trails[col_name].copy()
    else:
        return [None]*trails.shape[0]

# gets climate data via API and saves values
def addClimateDataAndSave(trails, printGap, outputCSV, forceOverwrite=False):

    numTrails = trails.shape[0]

    summerTemp = getInitalArray(trails, 'summer_temp')
    winterTemp = getInitalArray(trails, 'winter_temp')
    annualRain = getInitalArray(trails, 'annual_rain')
    
    # getting climate data one trail at a time
    for i, trail in enumerate(trails.iterrows()):
        trail = trail[1]
        if 'summer_temp' not in trail or 'winter_temp' not in trail or 'annual_rain' not in trail or \
            np.isnan(trail.summer_temp) or np.isnan(trail.winter_temp) or np.isnan(trail.annual_rain) or \
            forceOverwrite:
            
            response = requests.get('https://archive-api.open-meteo.com/v1/archive?' 
                                    + f'latitude={trail.lat}&longitude={trail.lng}&start_date' 
                                    + '=2011-01-01&end_date=2020-12-31&daily=temperature_2m_max,'
                                    + 'temperature_2m_min,rain_sum&timezone=America%2FNew_York')
            responseDaily = response.json()['daily']
            
            summerTemp[i] = np.quantile(responseDaily['temperature_2m_max'], 0.98) # 2% of days are hotter
            winterTemp[i] = np.quantile(responseDaily['temperature_2m_min'], 0.02) # 2% of days are colder
            annualRain[i] = np.sum(responseDaily['rain_sum'])/10 # average over 10 years
    
        # printing some progress notifications 
        if i%printGap==0:
            print(f'Climate data obtained for {i+1} out of {numTrails} trails')
            
    trails['summer_temp'] = summerTemp
    trails['winter_temp'] = winterTemp
    trails['annual_rain'] = annualRain

    # saving
    trails.to_csv(outputCSV, index=False)
    
# gets weather data via API and saves values
def addWeatherDataAndSave(trails, printGap, outputCSV, forceOverwrite=False):
    
    completedTrails = trails[trails.status == 0]
    numCompletedTrails = completedTrails.shape[0]
    
    maxTemp = getInitalArray(trails, 'max_temp')
    minTemp = getInitalArray(trails, 'min_temp')
    rain = getInitalArray(trails, 'rain')
    
    rainHours = getInitalArray(trails, 'rainHours')

    # getting weather data one trail at a time
    for i, trail in enumerate(completedTrails.iterrows()):
        trail = trail[1]
        if 'max_temp' not in trail or 'min_temp' not in trail or 'rain' not in trail \
            or np.isnan(trail.max_temp) or np.isnan(trail.min_temp) or np.isnan(trail.rain) or forceOverwrite:
            
            response = requests.get('https://archive-api.open-meteo.com/v1/archive?' 
                                    + f'latitude={trail.lat}&longitude={trail.lng}&' 
                                    + f'start_date={trail.start_date}&end_date={trail.end_date}' 
                                    + '&hourly=temperature_2m,rain&timezone=America%2FNew_York')
            responseHourly = response.json()['hourly']

            # I usually arrive and leave around noon, so I cut out the first and last 12 hours
            maxTemp[i] = np.max(responseHourly['temperature_2m'][12:-12]) # max over period
            minTemp[i] = np.min(responseHourly['temperature_2m'][12:-12]) # min over period
            rain[i] = np.sum(responseHourly['rain'][12:-12])
        
        # printing some progress notifications 
        if i%printGap==0:
            print(f'Weather data obtained for {i+1} out of {numCompletedTrails} trails')
    
    trails['max_temp'] = maxTemp
    trails['min_temp'] = minTemp
    trails['rain'] = rain

    # saving
    trails.to_csv(outputCSV, index=False)

# %%
### Getting Climate Data for My Trails

myTrails = pd.read_csv('MyTrails.csv')
addClimateDataAndSave(myTrails, 4, 'MyTrails.csv', forceOverwrite=False)
# Out:
# Climate data obtained for 1 out of 57 trails
# Climate data obtained for 5 out of 57 trails
# Climate data obtained for 9 out of 57 trails
# Climate data obtained for 13 out of 57 trails
# Climate data obtained for 17 out of 57 trails
# Climate data obtained for 21 out of 57 trails
# Climate data obtained for 25 out of 57 trails
# Climate data obtained for 29 out of 57 trails
# Climate data obtained for 33 out of 57 trails
# Climate data obtained for 37 out of 57 trails
# Climate data obtained for 41 out of 57 trails
# Climate data obtained for 45 out of 57 trails
# Climate data obtained for 49 out of 57 trails
# Climate data obtained for 53 out of 57 trails
# Climate data obtained for 57 out of 57 trails

# %%
### Getting Weather Data for My Trails

myTrails = pd.read_csv('MyTrails.csv')
addWeatherDataAndSave(myTrails, 1, 'MyTrails.csv', forceOverwrite=False)
# Out:
# Weather data obtained for 1 out of 20 trails
# Weather data obtained for 2 out of 20 trails
# Weather data obtained for 3 out of 20 trails
# Weather data obtained for 4 out of 20 trails
# Weather data obtained for 5 out of 20 trails
# Weather data obtained for 6 out of 20 trails
# Weather data obtained for 7 out of 20 trails
# Weather data obtained for 8 out of 20 trails
# Weather data obtained for 9 out of 20 trails
# Weather data obtained for 10 out of 20 trails
# Weather data obtained for 11 out of 20 trails
# Weather data obtained for 12 out of 20 trails
# Weather data obtained for 13 out of 20 trails
# Weather data obtained for 14 out of 20 trails
# Weather data obtained for 15 out of 20 trails
# Weather data obtained for 16 out of 20 trails
# Weather data obtained for 17 out of 20 trails
# Weather data obtained for 18 out of 20 trails
# Weather data obtained for 19 out of 20 trails
# Weather data obtained for 20 out of 20 trails

# %%
### Getting Climate Data for USA National Park Trails

usaTrails = pd.read_csv('AllTrailsUsaNationalParks.csv', engine='python')
usaTrails['lat'] = usaTrails.apply(lambda row: row._geoloc.split(': ', 2)[1][:-7], axis=1)
usaTrails['lng'] = usaTrails.apply(lambda row: row._geoloc.split(': ', 2)[2][:-1], axis=1)
addClimateDataAndSave(usaTrails, 20, 'AllTrailsUsaNationalParks.csv')
# Out:
# Climate data obtained for 1 out of 3313 trails
# Climate data obtained for 21 out of 3313 trails
# Climate data obtained for 41 out of 3313 trails
# Climate data obtained for 61 out of 3313 trails
# Climate data obtained for 81 out of 3313 trails
# Climate data obtained for 101 out of 3313 trails
# Climate data obtained for 121 out of 3313 trails
# Climate data obtained for 141 out of 3313 trails
# Climate data obtained for 161 out of 3313 trails
# Climate data obtained for 181 out of 3313 trails
# Climate data obtained for 201 out of 3313 trails
# Climate data obtained for 221 out of 3313 trails
# Climate data obtained for 241 out of 3313 trails
# Climate data obtained for 261 out of 3313 trails
# Climate data obtained for 281 out of 3313 trails
# Climate data obtained for 301 out of 3313 trails
# Climate data obtained for 321 out of 3313 trails
# Climate data obtained for 341 out of 3313 trails
# Climate data obtained for 361 out of 3313 trails
# Climate data obtained for 381 out of 3313 trails
# Climate data obtained for 401 out of 3313 trails
# Climate data obtained for 421 out of 3313 trails
# Climate data obtained for 441 out of 3313 trails
# Climate data obtained for 461 out of 3313 trails
# Climate data obtained for 481 out of 3313 trails
# Climate data obtained for 501 out of 3313 trails
# Climate data obtained for 521 out of 3313 trails
# Climate data obtained for 541 out of 3313 trails
# Climate data obtained for 561 out of 3313 trails
# Climate data obtained for 581 out of 3313 trails
# Climate data obtained for 601 out of 3313 trails
# Climate data obtained for 621 out of 3313 trails
# Climate data obtained for 641 out of 3313 trails
# Climate data obtained for 661 out of 3313 trails
# Climate data obtained for 681 out of 3313 trails
# Climate data obtained for 701 out of 3313 trails
# Climate data obtained for 721 out of 3313 trails
# Climate data obtained for 741 out of 3313 trails
# Climate data obtained for 761 out of 3313 trails
# Climate data obtained for 781 out of 3313 trails
# Climate data obtained for 801 out of 3313 trails
# Climate data obtained for 821 out of 3313 trails
# Climate data obtained for 841 out of 3313 trails
# Climate data obtained for 861 out of 3313 trails
# Climate data obtained for 881 out of 3313 trails
# Climate data obtained for 901 out of 3313 trails
# Climate data obtained for 921 out of 3313 trails
# Climate data obtained for 941 out of 3313 trails
# Climate data obtained for 961 out of 3313 trails
# Climate data obtained for 981 out of 3313 trails
# Climate data obtained for 1001 out of 3313 trails
# Climate data obtained for 1021 out of 3313 trails
# Climate data obtained for 1041 out of 3313 trails
# Climate data obtained for 1061 out of 3313 trails
# Climate data obtained for 1081 out of 3313 trails
# Climate data obtained for 1101 out of 3313 trails
# Climate data obtained for 1121 out of 3313 trails
# Climate data obtained for 1141 out of 3313 trails
# Climate data obtained for 1161 out of 3313 trails
# Climate data obtained for 1181 out of 3313 trails
# Climate data obtained for 1201 out of 3313 trails
# Climate data obtained for 1221 out of 3313 trails
# Climate data obtained for 1241 out of 3313 trails
# Climate data obtained for 1261 out of 3313 trails
# Climate data obtained for 1281 out of 3313 trails
# Climate data obtained for 1301 out of 3313 trails
# Climate data obtained for 1321 out of 3313 trails
# Climate data obtained for 1341 out of 3313 trails
# Climate data obtained for 1361 out of 3313 trails
# Climate data obtained for 1381 out of 3313 trails
# Climate data obtained for 1401 out of 3313 trails
# Climate data obtained for 1421 out of 3313 trails
# Climate data obtained for 1441 out of 3313 trails
# Climate data obtained for 1461 out of 3313 trails
# Climate data obtained for 1481 out of 3313 trails
# Climate data obtained for 1501 out of 3313 trails
# Climate data obtained for 1521 out of 3313 trails
# Climate data obtained for 1541 out of 3313 trails
# Climate data obtained for 1561 out of 3313 trails
# Climate data obtained for 1581 out of 3313 trails
# Climate data obtained for 1601 out of 3313 trails
# Climate data obtained for 1621 out of 3313 trails
# Climate data obtained for 1641 out of 3313 trails
# Climate data obtained for 1661 out of 3313 trails
# Climate data obtained for 1681 out of 3313 trails
# Climate data obtained for 1701 out of 3313 trails
# Climate data obtained for 1721 out of 3313 trails
# Climate data obtained for 1741 out of 3313 trails
# Climate data obtained for 1761 out of 3313 trails
# Climate data obtained for 1781 out of 3313 trails
# Climate data obtained for 1801 out of 3313 trails
# Climate data obtained for 1821 out of 3313 trails
# Climate data obtained for 1841 out of 3313 trails
# Climate data obtained for 1861 out of 3313 trails
# Climate data obtained for 1881 out of 3313 trails
# Climate data obtained for 1901 out of 3313 trails
# Climate data obtained for 1921 out of 3313 trails
# Climate data obtained for 1941 out of 3313 trails
# Climate data obtained for 1961 out of 3313 trails
# Climate data obtained for 1981 out of 3313 trails
# Climate data obtained for 2001 out of 3313 trails
# Climate data obtained for 2021 out of 3313 trails
# Climate data obtained for 2041 out of 3313 trails
# Climate data obtained for 2061 out of 3313 trails
# Climate data obtained for 2081 out of 3313 trails
# Climate data obtained for 2101 out of 3313 trails
# Climate data obtained for 2121 out of 3313 trails
# Climate data obtained for 2141 out of 3313 trails
# Climate data obtained for 2161 out of 3313 trails
# Climate data obtained for 2181 out of 3313 trails
# Climate data obtained for 2201 out of 3313 trails
# Climate data obtained for 2221 out of 3313 trails
# Climate data obtained for 2241 out of 3313 trails
# Climate data obtained for 2261 out of 3313 trails
# Climate data obtained for 2281 out of 3313 trails
# Climate data obtained for 2301 out of 3313 trails
# Climate data obtained for 2321 out of 3313 trails
# Climate data obtained for 2341 out of 3313 trails
# Climate data obtained for 2361 out of 3313 trails
# Climate data obtained for 2381 out of 3313 trails
# Climate data obtained for 2401 out of 3313 trails
# Climate data obtained for 2421 out of 3313 trails
# Climate data obtained for 2441 out of 3313 trails
# Climate data obtained for 2461 out of 3313 trails
# Climate data obtained for 2481 out of 3313 trails
# Climate data obtained for 2501 out of 3313 trails
# Climate data obtained for 2521 out of 3313 trails
# Climate data obtained for 2541 out of 3313 trails
# Climate data obtained for 2561 out of 3313 trails
# Climate data obtained for 2581 out of 3313 trails
# Climate data obtained for 2601 out of 3313 trails
# Climate data obtained for 2621 out of 3313 trails
# Climate data obtained for 2641 out of 3313 trails
# Climate data obtained for 2661 out of 3313 trails
# Climate data obtained for 2681 out of 3313 trails
# Climate data obtained for 2701 out of 3313 trails
# Climate data obtained for 2721 out of 3313 trails
# Climate data obtained for 2741 out of 3313 trails
# Climate data obtained for 2761 out of 3313 trails
# Climate data obtained for 2781 out of 3313 trails
# Climate data obtained for 2801 out of 3313 trails
# Climate data obtained for 2821 out of 3313 trails
# Climate data obtained for 2841 out of 3313 trails
# Climate data obtained for 2861 out of 3313 trails
# Climate data obtained for 2881 out of 3313 trails
# Climate data obtained for 2901 out of 3313 trails
# Climate data obtained for 2921 out of 3313 trails
# Climate data obtained for 2941 out of 3313 trails
# Climate data obtained for 2961 out of 3313 trails
# Climate data obtained for 2981 out of 3313 trails
# Climate data obtained for 3001 out of 3313 trails
# Climate data obtained for 3021 out of 3313 trails
# Climate data obtained for 3041 out of 3313 trails
# Climate data obtained for 3061 out of 3313 trails
# Climate data obtained for 3081 out of 3313 trails
# Climate data obtained for 3101 out of 3313 trails
# Climate data obtained for 3121 out of 3313 trails
# Climate data obtained for 3141 out of 3313 trails
# Climate data obtained for 3161 out of 3313 trails
# Climate data obtained for 3181 out of 3313 trails
# Climate data obtained for 3201 out of 3313 trails
# Climate data obtained for 3221 out of 3313 trails
# Climate data obtained for 3241 out of 3313 trails
# Climate data obtained for 3261 out of 3313 trails
# Climate data obtained for 3281 out of 3313 trails
# Climate data obtained for 3301 out of 3313 trails
